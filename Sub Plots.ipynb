# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
import scipy.stats as sc_stats
sns.set_context('talk')
x = np.random.randn(150)
x1 = np.random.randn(500)

y = np.random.randn(100)
r = sc_stats.lognorm.rvs(0.1, size=500)

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)

ax1.plot(x1, color=sns.xkcd_rgb['grey'], alpha=0.5, linestyle=':')
ax1.plot(x, color=sns.xkcd_rgb['denim blue'])

# ax1.set_xlim(right=500)

# ax2.plot(y, color=sns.xkcd_rgb['dark red'])
ax2.hist(x, cumulative=True, density='normed')
ax2.axhline(0.90, color=sns.xkcd_rgb['orange'], linestyle='-.', label='90% cumulative')
ax2.axvline(1, color=sns.xkcd_rgb['orange'], linestyle=':', linewidth=3.0)
ax3.hist(r)
ax4.plot(r)
ax4.axvline(200, color='red', linestyle='--', label='@ 200')
ax4.legend()
ax1.axhline(1, color='red')
fig.legend()
plt.gcf().set_size_inches(10, 5)
plt.show()

# %%
men_means, men_std = (20, 35, 30, 35, 27), (2, 3, 4, 1, 2)
women_means, women_std = (25, 32, 34, 20, 25), (3, 5, 2, 3, 3)
ind = np.arange(len(men_means))  # the x locations for the groups
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind - width/2, men_means, width, yerr=men_std,
                color='SkyBlue', label='Men')
rects2 = ax.bar(ind + width/2, women_means, width, yerr=women_std,
                color='IndianRed', label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(ind)
ax.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5'))
ax.legend()
plt.gcf().set_size_inches(10, 5)

plt.show()

# %%
with plt.xkcd():
    men_means, men_std = (20, 35, 30, 35, 27), (2, 3, 4, 1, 2)
    women_means, women_std = (25, 32, 34, 20, 25), (3, 5, 2, 3, 3)
    ind = np.arange(len(men_means))  # the x locations for the groups
    width = 0.35  # the width of the bars

    fig, ax = plt.subplots()
    rects1 = ax.bar(ind - width/2, men_means, width, yerr=men_std,
                    color='SkyBlue', label='Men')
    rects2 = ax.bar(ind + width/2, women_means, width, yerr=women_std,
                    color='IndianRed', label='Women')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Scores')
    ax.set_title('Scores by group and gender')
    ax.set_xticks(ind)
    ax.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5'))
    ax.legend()
    plt.gcf().set_size_inches(10, 5)

    plt.show()

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# sphinx_gallery_thumbnail_number = 2

# with plt.xkcd():

vegetables = ["cucumber", "tomato", "lettuce", "asparagus",
              "potato", "wheat", "barley"]
farmers = ["Farmer Joe", "Upland Bros.", "Smith Gardening",
           "Agrifun", "Organiculture", "BioGoods Ltd.", "Cornylee Corp."]

harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])


fig, ax = plt.subplots()
im = ax.imshow(harvest)

# We want to show all ticks...
ax.set_xticks(np.arange(len(farmers)))
ax.set_yticks(np.arange(len(vegetables)))
# ... and label them with the respective list entries
ax.set_xticklabels(farmers)
ax.set_yticklabels(vegetables)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(vegetables)):
    for j in range(len(farmers)):
        text = ax.text(j, i, harvest[i, j],
                       ha="center", va="center", color="white")

ax.set_title("Harvest of local farmers (in tons/year)")
fig.tight_layout()
plt.gcf().set_size_inches(10, 10)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt 

with plt.xkcd():
    x = np.arange(0, 10, 0.2)
    y = np.sin(x)

    # plot it
    f, (a0, a1) = plt.subplots(1,2, gridspec_kw = {'width_ratios':[3, 1]})
    a0.plot(x,y)
    a1.plot(y,x)
    f.suptitle('XKCD style plots')
    f.tight_layout()
    f.savefig('grid_figure.pdf')

# %%
import os

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
yearsFmt = mdates.DateFormatter('%b-%Y')

# Load a numpy record array from yahoo csv data with fields date, open, close,
# volume, adj_close from the mpl-data/example directory. The record array
# stores the date as an np.datetime64 with a day unit ('D') in the date column.
with cbook.get_sample_data(os.path.expanduser('~/dev/ml-notebooks/goog.npz')) as datafile:
    r = np.load(datafile)['price_data'].view(np.recarray)

fig, ax = plt.subplots()
ax.plot(r.date, r.adj_close)

# format the ticks
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(yearsFmt)
ax.xaxis.set_minor_locator(months)

# round to nearest years...
datemin = np.datetime64(r.date[0], 'Y')
datemax = np.datetime64(r.date[-1], 'Y') + np.timedelta64(1, 'Y')
ax.set_xlim(datemin, datemax)


# format the coords message box
def price(x):
    return '$%1.2f' % x
ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')
ax.format_ydata = price
ax.grid(True)

# rotates and right aligns the x labels, and moves the bottom of the
# axes up to make room for them
fig.autofmt_xdate()
plt.gcf().set_size_inches(10, 5)

plt.show()

# %%
ax = plt.subplot2grid((2, 2), (0, 0))

# %%
ax2 = plt.subplot2grid((3, 3), (1, 0), colspan=2)
ax3 = plt.subplot2grid((3, 3), (1, 2), rowspan=2)

# %%
ax1 = plt.subplot2grid((3, 3), (0, 0), colspan=3)
ax2 = plt.subplot2grid((3, 3), (1, 0), colspan=2)
ax3 = plt.subplot2grid((3, 3), (1, 2), rowspan=2)
ax4 = plt.subplot2grid((3, 3), (2, 0), colspan=1)
ax5 = plt.subplot2grid((3, 3), (2, 1), colspan=1)
rects1 = ax3.bar(ind - width/2, men_means, width, yerr=men_std, color='SkyBlue', label='Men')
rects2 = ax3.bar(ind + width/2, women_means, width, yerr=women_std, color='IndianRed', label='Women')
ax3.set_xticks(ind)
ax3.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5'))

ax3.legend()
plt.gcf().set_size_inches(10, 10)

# %%
import pandas as pd
men_means, men_std = (20, 35, 30, 35, 27), (2, 3, 4, 1, 2)
women_means, women_std = (25, 32, 34, 20, 25), (3, 5, 2, 3, 3)
ind = np.arange(len(men_means))  # the x locations for the groups
df = pd.DataFrame({'mean_means': men_means, 'men_std': men_std, 'women_means': women_means, 'women_std':women_std })
display(ind)
df.head()
# Out:
# array([0, 1, 2, 3, 4])
#    mean_means  men_std  women_means  women_std
# 0          20        2           25          3
# 1          35        3           32          5
# 2          30        4           34          2
# 3          35        1           20          3
# 4          27        2           25          3

# %%
ax1 = plt.subplot2grid((3, 3), (0, 0), colspan=3)
ax2 = plt.subplot2grid((3, 3), (1, 0), colspan=2)
ax3 = plt.subplot2grid((3, 3), (1, 2), rowspan=2)
ax4 = plt.subplot2grid((3, 3), (2, 0), colspan=1)
ax5 = plt.subplot2grid((3, 3), (2, 1), colspan=1)
df[['mean_means', 'women_means']].reset_index().plot('index', ax=ax3, kind='bar', legend=False)
ax3.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5'))

plt.gcf().legend()
plt.gcf().set_size_inches(10, 10)
